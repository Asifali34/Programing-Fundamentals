# %%
def read(n):
    f=open("x.txt","r")
    print(f.read())
read("x.txt")

print("NEXT FUNCTION")

def line(n,a):
    with open(n,'r') as f:
        lines = list(f.readlines())
        for line in lines[0:a]:
            print(line)
line("x.txt",2)
print("NEXT FUNCTION")            
def append(n,b):
    f=open(n,"a+")
    f.write(b)
    f.close()
    f=open(n,"r")
    print(f.read())
append("x.txt","\nthis is a new line.")
# Out:
# This is file handling programm
# this is a new line.
# NEXT FUNCTION
# This is file handling programm
#
# this is a new line.
# NEXT FUNCTION
# This is file handling programm
# this is a new line.
# this is a new line.

# %%
def function(filename):
    f=open(filename,"r")
    contents = f.read().split(" ")
    length = 0
    for x in contents:
        if len(x)>length:
            length = len(x)
            longest_word = x
    return longest_word
function("x.txt")
# Out:
# 'programm\nthis'

# %%
def function(a):
    y=[]
    b=" "
    name=input("enter the student name: ")
    y.append(str(name))
    registration=input("enter the registration number: ")
    y.append(registration)
    title=input("enter the degree title: ")
    y.append(str(title))
    sem=input("enter the semester: ")
    y.append(str(sem))
    CGPA=float(input("enter the cpga: "))
    y.append(str(CGPA))
    DOB=input("enter date of birth: "  )
    y.append(str(DOB))
    city=input("enter the city name: ")
    y.append(str(city))
    
    f=open(a,"a+")
    f.write(' '.join(y))
    return y
function("x.txt")
# Out:
# enter the student name: saleem
# enter the registration number: 2
# enter the degree title: 3
# enter the semester: 3
# enter the cpga: 3.4
# enter date of birth: 3/4/2003
# enter the city name: moro
# ['saleem', '2', '3', '3', '3.4', '3/4/2003', 'moro']

# %%
add=0       
a = 0
a1 = 0
b = 0
b1 = 0
c = 0
c1 = 0
c2 = 0
c3 = 0
c4 = 0
k="yes"
print(" You are warmly welcome To Gloria Jean's ")

while k !="no" and k!="n":
    
    menu=int(input("Please check the Menu"))
    if menu==1:
        print(" ESPRESSO & MOCHA CHILLERS ")
        print("--------------------------------------------")
    
        order=int(input("Please enter your Order:"))
        if order==1:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" Very Vanilla Chillers    Small=361 ")
                n=int(input("How Much"))
                p=361*n
                x=x+p
                print("Very Vanilla Chillers",n,"Small items:",x)
            elif  x==2:
                print(" Very Vanilla Chillers     Regular=409 ")
                n=int(input("How Much"))
                p=409*n
                x=x+p
                print("Very Vanilla Chillers",n,"Regular items:",x)
        elif order==2:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" Cocoa Loco     Small=361 ")
                n=int(input("How Much"))
                p=361*n
                a1=a1+p
                print("Cocoa Loco",n,"Small items:",a1)
            elif  x==2:
                print(" Cocoa Loco    Regular=409 ")
                n=int(input("How Much"))
                p=409*n
                a1=a1+p
                print("Cocoa Loco",n,"Regular items",a1)
            
        elif order==3:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" Cookies N Cream     Small=361 ")
                n=int(input("How Much"))
                p=361*n
                b=b+p
                print("Cookies N Cream",n,"Small items:",b)
            elif  x==2:
                print(" Cookies N Cream     Regular=409 ")
                n=int(input("How Much"))
                p=409*n
                b=b+p
                print("Cookies N Cream",n,"Regular items:",b)
        elif order==4:
            x=int(input("Please Select your choice:"))
            if x==1:
                print("  Hazelnut MOCHA CHILLERS    Small=396 ")
                n=int(input("How Much"))
                p=396*n
                b1=b1+p
                print(" Hazelnut MOCHA CHILLERS",n,"Small items:",b1)
            elif  x==2:
                print(" Hazelnut MOCHA CHILLERS     Regular=461 ")
                n=int(input("How Much"))
                p=461*n
                b1=b1+p
                print("Hazelnut MOCHA CHILLERS",n,"Regular items:",b1)
        elif order==5:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" Chocolate Macadana CHILLERS     Small=396 ")
                n=int(input("How Much"))
                p=396*n
                c=c+p
                print("Chocolate Macadana CHILLERS",n,"Small items <> Paid :",c)
            elif  x==2:
                print(" Chocolate Macadana CHILLERS     Regular=461 ")
                n=int(input("How Much"))
                p=461*n
                c=c+p
                print("Chocolate Macadana CHILLERS",n,"Regular items:",c)
        elif order==6:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" Italian Dolce CHILLERS    Small=396 ")
                n=int(input("How Much"))
                p=396*n
                c1=c1+p
                print("Italian Dolce CHILLERS",n,"Small items :",c1)
            elif  x==2:
                print("Italian Dolce CHILLERS     Regular=461 ")
                n=int(input("How Much"))
                p=461*n
                c1=c1+p
                print("Italian Dolce CHILLERS",n,"Regular items :",c1)
        elif order==7:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" Caramel Nut CHILLERS      Small=396 ")
                n=int(input("How Much"))
                p=396*n
                c2=c2+p
                print("Caramel Nut CHILLERS ",n,"Small items :",c2)
            elif  x==2:
                print(" Caramel Nut CHILLERS      Regular=461 ")
                n=int(input("How Much"))
                p=461*n
                c2=c2+p
                print("Caramel Nut CHILLERS ",n,"Regular items :",c2)
        elif order==8:
            a=int(input("Please Select your choice:"))
            if x==1:
                print(" Tiramisu CHILLERS      Small=399 ")
                n=int(input("How Much"))
                p=399*n
                c3=c3+p
                print("Tiramisu CHILLERS ",n,"Small items :",c3)
            elif  x==2:
                print(" Tiramisu CHILLERS      Regular=509 ")
                n=int(input("How Much"))
                p=509*n
                c3=c3+p
                print("Tiramisu CHILLERS ",n,"Regular items :",c3)
        elif order==9:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" Toffee NUT CHILLERS     Small=399 ")
                n=int(input("How Much"))
                p=399*n
                c4=c4+p
                print("Toffee NUT CHILLERS",n,"Small items :",c4)
            elif  x==2:
                print(" Toffee NUT CHILLERS     Regular=509 ")
                n=int(input("How Much"))
                p=509*n
                c4=c4+p
                print("Toffee NUT CHILLERS",n,"Regular items :",c4)
    if menu==2:
        print(" CHOCOLATE CHILLERS ")
        print("--------------------------------------------")
    
        order=int(input("Please enter your Order:"))
        if order==1:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" ORIGINAL ICED CHOCOLATE     Small=348 ")
                n=int(input("How Much"))
                p=348*n
                c5=c5+p
                print("ORIGINAL ICED CHOCOLATE",n,"Small items  :",c5)
            elif  x==2:
                print(" ORIGINAL ICED CHOCOLATE     Regular=365 ")
                n=int(input("How Much"))
                p=365*n
                c5=c5+p
                print("ORIGINAL ICED CHOCOLATE",n,"Regular items  :",c5)
        elif order==2:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" WHITE ICED CHOCOLATE     Small=348 ")
                n=int(input("How Much"))
                p=348*n
                c6=c6+p
                print("WHITE ICED CHOCOLATE",n,"Small items <> Paid :",c6)
            elif  x==2:
                print(" WHITE ICED CHOCOLATE    Regular=365 ")
                n=int(input("How Much"))
                p=365*n
                c6=c6+p
                print("WHITE ICED CHOCOLATE",n,"Regular items <> Paid :",c6)
        elif order==3:
            x=int(input("Please Select your choice:"))
            if x==1:
                print(" CHOCOLATE Delight     Small=348 ")
                n=int(input("How Much"))
                p=348*n
                c7=c7+p
                print("CHOCOLATE Delight",n,"Small items <> Paid :",c7)
            elif  a==2:
                print(" CHOCOLATE Delight     Regular=400 ")
                n=int(input("How Much"))
                p=400*n
                c7=c7+p
                print("CHOCOLATE Delight",n,"Regular items <> Paid :",c7)
    k=input("do you want to order again?" )
# Out:
#  You are warmly welcome To Gloria Jean's
# Please check the Menu1
#  ESPRESSO & MOCHA CHILLERS
# --------------------------------------------
# Please enter your Order:1
# Please Select your choice:1
#  Very Vanilla Chillers    Small=361
# How Much1
# Very Vanilla Chillers 1 Small items: 362
# do you want to order again?no
